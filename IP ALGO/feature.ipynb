# %% [markdown]
# #  Edge Detection

# %% [markdown]
# Edge is a rapid change in image intensity in small region.
#
# ## 1D edge detection
#
# Take the first derivative of image intensity, Local extrema indicate edges.
#
# ## 2D edge detection
#
# Gradient(partial derivative) represent the direction of most rapid change in intensity.

# %% [markdown]
# ![1_NplAYvrHR3qlD-OMKZUTKA.png](data:image/png;base64,...)

# %% [markdown]
# ![](https://slideplayer.com/slide/12725297/76/images/16/Comparing+Edge+Operators.jpg)

# %% [markdown]
# ![](https://slidetodoc.com/presentation_image_h/0a5094c9f689ab15a39f984f0176ba06/image-30.jpg)

# %% [markdown]
# # Corner Detection

# %% [markdown]
# Corner is a point where two edges meet i.e. raoid change in image intensity in two direction.

# %% [markdown]
# ![](https://slideplayer.com/slide/13494356/82/images/30/The+second+moment+matrix.jpg)

# %% [markdown]
# ![](https://i.stack.imgur.com/4yCvt.png)

# %% [markdown]
# ![](https://images.slideplayer.com/28/9367385/slides/slide_49.jpg)

# %% [markdown]
# # Blob Detection

# %% [markdown]
# Blob are the regions or points in image that differ in properties like brightness or color compared to the surroundings.
